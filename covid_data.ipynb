# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
covid = pd.read_csv("time_series_covid_19_confirmed.csv")
covid
# Out:
#                   Province/State  Country/Region       Lat      Long  1/22/20  \
# 0                          Anhui  Mainland China  31.82571  117.2264        1
# 1                        Beijing  Mainland China  40.18238  116.4142       14
# 2                      Chongqing  Mainland China  30.05718  107.8740        6
# 3                         Fujian  Mainland China  26.07783  117.9895        1
# 4                          Gansu  Mainland China  36.06110  103.8343        0
# ..                           ...             ...       ...       ...      ...
# 71  Diamond Princess cruise ship          Others  35.44370  139.6380        0
# 72          San Diego County, CA              US  32.71570 -117.1611        0
# 73               San Antonio, TX              US  29.42410  -98.4936        0
# 74                           NaN           Egypt  26.82060   30.8025        0
# 75                           NaN            Iran  32.42790   53.6880        0
#
# ...

# %%
covid.describe()
# Out:
#              Lat        Long     1/22/20     1/23/20     1/24/20     1/25/20  \
# count  76.000000   76.000000   76.000000   76.000000   76.000000   76.000000
# mean   30.250168   59.663831    7.302632    8.592105   12.381579   18.868421
# std    19.274793   86.753709   50.899383   50.941058   63.194297   87.707140
# min   -37.813600 -123.121000    0.000000    0.000000    0.000000    0.000000
# 25%    24.687853   12.038425    0.000000    0.000000    0.000000    0.000000
# 50%    33.834960  105.154900    0.000000    0.000000    1.000000    2.000000
# 75%    40.754778  116.617250    1.000000    3.000000    5.000000   10.250000
# max    61.924100  153.025100  444.000000  444.000000  549.000000  761.000000
#
#            1/26/20      1/27/20      1/28/20      1/29/20  ...       2/11/20  \
# count    76.000000    76.000000    76.000000    76.000000  ...     76.000000
# mean     27.868421    38.513158    73.394737    81.131579  ...    589.513158
# ...

# %%
covid.rename(columns={"2/20/20": "feb_twenty"}, inplace=True)
covid
# Out:
#                   Province/State  Country/Region       Lat      Long  1/22/20  \
# 0                          Anhui  Mainland China  31.82571  117.2264        1
# 1                        Beijing  Mainland China  40.18238  116.4142       14
# 2                      Chongqing  Mainland China  30.05718  107.8740        6
# 3                         Fujian  Mainland China  26.07783  117.9895        1
# 4                          Gansu  Mainland China  36.06110  103.8343        0
# ..                           ...             ...       ...       ...      ...
# 71  Diamond Princess cruise ship          Others  35.44370  139.6380        0
# 72          San Diego County, CA              US  32.71570 -117.1611        0
# 73               San Antonio, TX              US  29.42410  -98.4936        0
# 74                           NaN           Egypt  26.82060   30.8025        0
# 75                           NaN            Iran  32.42790   53.6880        0
#
# ...

# %%
covid.groupby("Country/Region").feb_twenty.sum().sort_values(ascending=False)
# Out:
# Country/Region
# Mainland China          74999
# Others                    634
# South Korea               104
# Japan                      94
# Singapore                  84
# Hong Kong                  68
# Thailand                   35
# Taiwan                     24
# Malaysia                   22
# Germany                    16
# Vietnam                    16
# Australia                  15
# US                         15
# France                     12
# Macau                      10
# United Arab Emirates        9
# UK                          9
# Canada                      8
# Iran                        5
# Philippines                 3
# India                       3
# Italy                       3
# Spain                       2
# Russia                      2
# Sweden                      1
# Sri Lanka                   1
# Nepal                       1
# Finland                     1
# Egypt                       1
# Cambodia                    1
# ...

# %%
sns.
